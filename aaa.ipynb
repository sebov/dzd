# %%
from pprint import pprint
from river import datasets

dataset = datasets.Phishing()

for x, y in dataset:
    pprint(x)
    print(y)
# Out:
# {'age_of_domain': 1,
#  'anchor_from_other_domain': 0.0,
#  'empty_server_form_handler': 0.0,
#  'https': 0.0,
#  'ip_in_url': 1,
#  'is_popular': 0.5,
#  'long_url': 1.0,
#  'popup_window': 0.0,
#  'request_from_other_domain': 0.0}
# True
# {'age_of_domain': 1,
#  'anchor_from_other_domain': 0.0,
#  'empty_server_form_handler': 1.0,
#  'https': 0.5,
#  'ip_in_url': 0,
#  'is_popular': 0.5,
#  'long_url': 0.0,
#  'popup_window': 0.0,
#  'request_from_other_domain': 0.5}
# True
# {'age_of_domain': 1,
#  'anchor_from_other_domain': 0.5,
#  'empty_server_form_handler': 0.0,
#  'https': 1.0,
#  'ip_in_url': 0,
#  'is_popular': 0.5,
#  'long_url': 0.0,
#  'popup_window': 0.0,
#  'request_from_other_domain': 0.0}
# True
# {'age_of_domain': 0,
#  'anchor_from_other_domain': 0.0,
#  'empty_server_form_handler': 0.0,
#  'https': 1.0,
#  'ip_in_url': 0,
#  'is_popular': 1.0,
#  'long_url': 0.5,
#  'popup_window': 0.0,
#  'request_from_other_domain': 0.0}
# True
# {'age_of_domain': 1,
# ...

# %%
dataset
# Out:
# Phishing websites.
#
# This dataset contains features from web pages that are classified as phishing or not.
#
#     Name  Phishing
#     Task  Binary classification
#  Samples  1,250
# Features  9
#   Sparse  False
#     Path  /home/sebov/synced/backup/workspace/dzd/.venv/lib/python3.12/site-packages/river/datasets/phishing.csv.gz
