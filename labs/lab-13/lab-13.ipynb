# %% [markdown]
# # Lab 13 - Multimodal Data Exploration
#
# During this lab we are going to explore data of more than one modality.

# %%
import deeplake

# Create a local dataset
# ds = deeplake.create("data/dataset1")

ds = deeplake.open("data/dataset1")

# %%
ds.add_column("ids", "int32")
ds.add_column("labels", "text")
# Out:
# ---------------------------------------------------------------------------
# ColumnAlreadyExistsError                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ds.add_column("ids", "int32")
#       2 ds.add_column("labels", "text")
#
# ColumnAlreadyExistsError: Column 'ids' already exists

# %%
ds.append({
    "ids": [1, 2, 3],
    "labels": ["cat", "dog", "bird"],
})
ds.commit()

# %%
ds["ids"][0]
# Out:
# array(1, dtype=int32)

# %%
ds["ids"]
# Out:
# Column(name='ids', dtype=int32, length=9) at 0x764a443ca170
